# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.read_csv ('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %% [markdown]
# Review Data

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
df.isnull().sum()
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# dtype: int64

# %% [markdown]
# Remove Unnessary Columns and Clean Data

# %%
drop_cols = ['Number Scoring CR', 'Percent Scoring CR']
df.drop(drop_cols, inplace=True, axis=1)

# %% [markdown]
# Update missing values

# %%
df.isnull().sum()
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# dtype: int64

# %%
missing_values = ['s', 'na']
df = pd.read_csv ('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values = missing_values)

# %%
drop_cols = ['Number Scoring CR', 'Percent Scoring CR']
df.drop(drop_cols, inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212331 non-null  object
#  1   School Name                  212331 non-null  object
#  2   School Level                 212331 non-null  object
#  3   Regents Exam                 212321 non-null  object
#  4   Year                         212331 non-null  int64
#  5   Total Tested                 212331 non-null  int64
#  6   Mean Score                   137109 non-null  float64
#  7   Number Scoring Below 65      137109 non-null  float64
#  8   Percent Scoring Below 65     137109 non-null  float64
#  9   Number Scoring 65 or Above   137109 non-null  float64
#  10  Percent Scoring 65 or Above  137109 non-null  float64
#  11  Number Scoring 80 or Above   137109 non-null  float64
# ...

# %%
df=df.fillna(df.median())

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested  Mean Score  \
# 0  Common Core Algebra  2017             4        65.4
# 1   Living Environment  2015            16        77.9
# 2   Living Environment  2016             9        74.0
# 3  Common Core Algebra  2016             3        65.4
# 4  Common Core Algebra  2017             2        65.4
#
#    Number Scoring Below 65  Percent Scoring Below 65  \
# 0                     13.0                      40.2
# 1                      1.0                       6.3
# 2                      1.0                      11.1
# 3                     13.0                      40.2
# ...

# %%
df.tail()
# Out:
#        School DBN           School Name School Level  \
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested  Mean Score  \
# 212326           Living Environment  2016             8        65.4
# 212327           Living Environment  2016             5        65.4
# 212328           Living Environment  2017             6        65.4
# 212329           Living Environment  2017             4        65.4
# 212330  U.S. History and Government  2015             1        65.4
#
#         Number Scoring Below 65  Percent Scoring Below 65  \
# 212326                     13.0                      40.2
# 212327                     13.0                      40.2
# ...

# %%
df.isnull().sum()
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# School DBN                     0
# School Name                    0
# School Level                   0
# Regents Exam                   0
# Year                           0
# Total Tested                   0
# Mean Score                     0
# Number Scoring Below 65        0
# Percent Scoring Below 65       0
# Number Scoring 65 or Above     0
# Percent Scoring 65 or Above    0
# Number Scoring 80 or Above     0
# Percent Scoring 80 or Above    0
# dtype: int64

# %% [markdown]
# Create Data Subset

# %%
df2= df[['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year', 'Total Tested', 'Mean Score']]

# %% [markdown]
# #Question: How does the selected school test in the areas of Math and English?

# %% [markdown]
# Identify school and school district to create subset

# %%
sorted(df2['School Name'].unique())
# Out:
# ['47 The American Sign Language and English Secondar',
#  'A. Philip Randolph Campus High School',
#  'ACORN Community High School',
#  'Abraham Lincoln High School',
#  'Abraham Lincoln Yabc',
#  'Academy For Personal Leadership And Excellence',
#  'Academy for Careers in Television and Film',
#  'Academy for College Preparation and Career Explora',
#  'Academy for Conservation and the Environment',
#  'Academy for Environmental Leadership',
#  'Academy for Health Careers',
#  'Academy for Language and Technology',
#  'Academy for New Americans',
#  'Academy for Scholarship and Entrepreneurship: A Co',
#  'Academy for Social Action',
#  'Academy for Software Engineering',
#  'Academy for Young Writers',
#  'Academy of American Studies',
#  'Academy of Applied Mathematics and Technology',
#  'Academy of Arts and Letters',
#  'Academy of Finance and Enterprise',
#  'Academy of Hospitality and Tourism',
#  'Academy of Innovative Technology',
# ...

# %%
pace= df2[df2['School Name']== 'Pace High School']

# %%
pace.head(2)
# Out:
#     School DBN       School Name School Level           Regents Exam  Year  \
# 400     02M298  Pace High School  High school    Common Core English  2017
# 537     02M298  Pace High School  High school  Algebra2/Trigonometry  2015
#
#      Total Tested  Mean Score
# 400            98        81.8
# 537            53        58.8

# %%
man = df2[df2['School DBN'].str.contains('M')]

# %%
man.head(2)
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
#
#           Regents Exam  Year  Total Tested  Mean Score
# 0  Common Core Algebra  2017             4        65.4
# 1   Living Environment  2015            16        77.9

# %%
man_high = man[man['School Level']== 'High school']

# %%
man_high.head(2)
# Out:
#    School DBN                 School Name School Level           Regents Exam  \
# 18     01M292  Orchard Collegiate Academy  High school  Algebra2/Trigonometry
# 19     01M292  Orchard Collegiate Academy  High school  Algebra2/Trigonometry
#
#     Year  Total Tested  Mean Score
# 18  2015             5        65.4
# 19  2016             5        65.4

# %%
sorted(man_high['School Name'].unique())
# Out:
# ['47 The American Sign Language and English Secondar',
#  'A. Philip Randolph Campus High School',
#  'Academy for Social Action',
#  'Academy for Software Engineering',
#  'Art and Design High School',
#  'Bard High School Early College',
#  'Baruch College Campus High School',
#  'Beacon High School',
#  'Bread & Roses Integrated Arts High School',
#  'Broome Street Academy Charter School',
#  'Business Of Sports School',
#  'Cascades High School',
#  'Central Park East High School',
#  'Chelsea Career and Technical Education High School',
#  'Coalition School for Social Change',
#  'Edward A. Reynolds West Side High School',
#  'Eleanor Roosevelt High School',
#  'Emma Lazarus High School',
#  'Essex Street Academy',
#  'Facing History School, The',
#  'Fiorello H. LaGuardia High School of Music & Art a',
#  'Food and Finance High School',
#  'Forsyth Satellite Academy',
#  'Frank Mccourt High School',
#  'George Washington Yabc',
#  'Gramercy Arts High School',
# ...

# %%
pace_eng= pace[pace['Regents Exam'].str.contains('English')]
pace_eng.head(2)
# Out:
#     School DBN       School Name School Level         Regents Exam  Year  \
# 400     02M298  Pace High School  High school  Common Core English  2017
# 545     02M298  Pace High School  High school  Common Core English  2015
#
#      Total Tested  Mean Score
# 400            98        81.8
# 545           106        78.1

# %%
pace_math= pace[pace['Regents Exam'].str.contains('Algebra')]
pace_math.head(2)
# Out:
#     School DBN       School Name School Level           Regents Exam  Year  \
# 537     02M298  Pace High School  High school  Algebra2/Trigonometry  2015
# 538     02M298  Pace High School  High school  Algebra2/Trigonometry  2016
#
#      Total Tested  Mean Score
# 537            53        58.8
# 538            69        55.9

# %% [markdown]
# Create Visualizations for Pace High School scoring in Math and English

# %%
sns.boxplot(data=pace_math ,x='Mean Score', y='Regents Exam', hue='Year', showfliers = False)

# %%
sns.boxplot(data=pace_eng ,x='Mean Score', y='Regents Exam', hue='Year', showfliers = False)

# %% [markdown]
# Over all test scores

# %%
x=pace_math['Regents Exam']
y=pace_math['Mean Score']
plt.barh(x,y, height=0.2, color='green')
plt.show()

# %%
x=pace_eng['Regents Exam']
y=pace_eng['Mean Score']
plt.barh(x,y, height=0.2, color='DarkOrange')
plt.show()

# %% [markdown]
# How does Pace High School test scores compare to the entire borough for Math and English?

# %%
man_high_eng= man_high[man_high['Regents Exam'].str.contains('English')]

# %%
man_high_eng.head(2)
# Out:
#    School DBN                 School Name School Level         Regents Exam  \
# 25     01M292  Orchard Collegiate Academy  High school  Common Core English
# 26     01M292  Orchard Collegiate Academy  High school  Common Core English
#
#     Year  Total Tested  Mean Score
# 25  2015            34        61.5
# 26  2016            46        67.2

# %%
man_high_math= man_high[man_high['Regents Exam'].str.contains('Algebra')]

# %%
man_high_math.head(2)
# Out:
#    School DBN                 School Name School Level           Regents Exam  \
# 18     01M292  Orchard Collegiate Academy  High school  Algebra2/Trigonometry
# 19     01M292  Orchard Collegiate Academy  High school  Algebra2/Trigonometry
#
#     Year  Total Tested  Mean Score
# 18  2015             5        65.4
# 19  2016             5        65.4

# %%
sns.boxplot(data=man_high_eng ,x='Mean Score', y='Regents Exam', hue='Year', showfliers = False)

# %%
sns.boxplot(data=man_high_math ,x='Mean Score', y='Regents Exam', hue='Year', showfliers = False)

# %%
x=man_high_eng['Regents Exam']
y=man_high_eng['Mean Score']
plt.barh(x,y, height=0.2, color='DarkOrange')
plt.show()

# %%
x=man_high_math['Regents Exam']
y=man_high_math['Mean Score']
plt.barh(x,y, height=0.2, color='green')
plt.show()

# %% [markdown]
# How do testing scores of Manhattan High Schools compare to the Bronx High Schools in the areas of Math and English?

# %%
bx = df2[df2['School DBN'].str.contains('X')]

# %%
bx.head(2)
# Out:
#      School DBN                   School Name School Level  \
# 1125     10X504                  Kennedy Yabc  High school
# 3923     07X029  P.S./M.S. 029 Melrose School          K-8
#
#              Regents Exam  Year  Total Tested  Mean Score
# 1125  Common Core Algebra  2015             2        65.4
# 3923  Common Core Algebra  2015            29        65.0

# %%
bx_high = bx[bx['School Level']== 'High school']
bx_high.head(2)
# Out:
#      School DBN                                        School Name  \
# 1125     10X504                                       Kennedy Yabc
# 3987     07X259  H.E.R.O. High (Health, Education, and Research...
#
#      School Level           Regents Exam  Year  Total Tested  Mean Score
# 1125  High school    Common Core Algebra  2015             2        65.4
# 3987  High school  Algebra2/Trigonometry  2016            16        40.1

# %%
bx_high_eng= bx_high[bx_high['Regents Exam'].str.contains('English')]
bx_high_eng.head(2)
# Out:
#      School DBN                                        School Name  \
# 3993     07X259  H.E.R.O. High (Health, Education, and Research...
# 3994     07X259  H.E.R.O. High (Health, Education, and Research...
#
#      School Level         Regents Exam  Year  Total Tested  Mean Score
# 3993  High school  Common Core English  2015           104        71.0
# 3994  High school  Common Core English  2016           119        67.8

# %%
bx_high_math= bx_high[bx_high['Regents Exam'].str.contains('Algebra')]
bx_high_math.head(2)
# Out:
#      School DBN                                        School Name  \
# 1125     10X504                                       Kennedy Yabc
# 3987     07X259  H.E.R.O. High (Health, Education, and Research...
#
#      School Level           Regents Exam  Year  Total Tested  Mean Score
# 1125  High school    Common Core Algebra  2015             2        65.4
# 3987  High school  Algebra2/Trigonometry  2016            16        40.1

# %%
sns.boxplot(data=bx_high_eng ,x='Mean Score', y='Regents Exam', hue='Year', showfliers = False)

# %%
sns.boxplot(data=bx_high_math ,x='Mean Score', y='Regents Exam', hue='Year', showfliers = False)

# %%
x=bx_high_eng['Regents Exam']
y=bx_high_eng['Mean Score']
plt.barh(x,y, height=0.2, color='DarkOrange')
plt.show()

# %%
x=bx_high_math['Regents Exam']
y=bx_high_math['Mean Score']
plt.barh(x,y, height=0.2, color='green')
plt.show()

# %% [markdown]
# Overall Comparison

# %%
pace_eng.median()
# Out:
# Year            2016.0
# Total Tested      22.0
# Mean Score        77.1
# dtype: float64

# %%
man_high_eng.median()
# Out:
# Year            2016.0
# Total Tested      22.0
# Mean Score        65.4
# dtype: float64

# %%
bx_high_eng.median()
# Out:
# Year            2016.0
# Total Tested      21.0
# Mean Score        65.4
# dtype: float64

# %%
pace_math.median()
# Out:
# Year            2016.0
# Total Tested      21.0
# Mean Score        65.4
# dtype: float64

# %%
man_high_math.median()
# Out:
# Year            2016.0
# Total Tested      16.0
# Mean Score        65.4
# dtype: float64

# %%
bx_high_math.median()
# Out:
# Year            2016.0
# Total Tested      15.0
# Mean Score        65.4
# dtype: float64

# %%
## Conclusion

# %% [markdown]
# In conclusion, Pace High School performer lower than Manhattan High Schools overall in the area of Math. Additional, Manhattan High Schools test lower than Bronx High Schools overall in the area of Math. Although Pace High School performed better with English Regents exams vs math, the high school did not out perform the high schools in their borough over all(Manhattan). Furthermore, Manhattan high school performance in English is in line with Bronx high schools.
